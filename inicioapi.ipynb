# %%
# !pip install requests

# %%
import requests

# %%
import requests

url = "https://api.themoviedb.org/3/authentication"

headers = {
    "accept": "application/json",
    "Authorization": " BEARER "
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"success":true,"status_code":1,"status_message":"Success."}

# %%
import requests

url = "https://api.themoviedb.org/3/genre/movie/list?language=en"

headers = {
    "accept": "application/json",
    "Authorization": ""
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'genres': [{'id': 28, 'name': 'Action'}, {'id': 12, 'name': 'Adventure'}, {'id': 16, 'name': 'Animation'}, {'id': 35, 'name': 'Comedy'}, {'id': 80, 'name': 'Crime'}, {'id': 99, 'name': 'Documentary'}, {'id': 18, 'name': 'Drama'}, {'id': 10751, 'name': 'Family'}, {'id': 14, 'name': 'Fantasy'}, {'id': 36, 'name': 'History'}, {'id': 27, 'name': 'Horror'}, {'id': 10402, 'name': 'Music'}, {'id': 9648, 'name': 'Mystery'}, {'id': 10749, 'name': 'Romance'}, {'id': 878, 'name': 'Science Fiction'}, {'id': 10770, 'name': 'TV Movie'}, {'id': 53, 'name': 'Thriller'}, {'id': 10752, 'name': 'War'}, {'id': 37, 'name': 'Western'}]}

# %%
import requests

url = "https://api.themoviedb.org/3/movie/popular?language=en-US&page=1&region=ES"

headers = {
    "accept": "application/json",
    "Authorization": ""
}

response = requests.get(url, headers=headers)

print(response.json())
# Out:
# {'page': 1, 'results': [{'adult': False, 'backdrop_path': '/4woSOUD0equAYzvwhWBHIJDCM88.jpg', 'genre_ids': [28, 27, 53], 'id': 1096197, 'original_language': 'en', 'original_title': 'No Way Up', 'overview': "Characters from different backgrounds are thrown together when the plane they're travelling on crashes into the Pacific Ocean. A nightmare fight for survival ensues with the air supply running out and dangers creeping in from all sides.", 'popularity': 1532.906, 'poster_path': '/hu40Uxp9WtpL34jv3zyWLb5zEVY.jpg', 'release_date': '2024-01-18', 'title': 'No Way Up', 'video': False, 'vote_average': 6.479, 'vote_count': 499}, {'adult': False, 'backdrop_path': '/qrGtVFxaD8c7et0jUtaYhyTzzPg.jpg', 'genre_ids': [28, 878, 12], 'id': 823464, 'original_language': 'en', 'original_title': 'Godzilla x Kong: The New Empire', 'overview': 'Following their explosive showdown, Godzilla and Kong must reunite against a colossal undiscovered threat hidden within our world, challenging their very existen
# ...

# %% [markdown]
# PRUEBAS 20/03/24

# %%
import requests

url = "https://api.themoviedb.org/3/discover/movie?include_adult=false&include_video=false&language=en-US&page=1&sort_by=popularity.desc"

headers = {
    "accept": "application/json",
    "Authorization": ""
}

response = requests.get(url, headers=headers)

print(response.text)
# Out:
# {"page":1,"results":[{"adult":false,"backdrop_path":"/4woSOUD0equAYzvwhWBHIJDCM88.jpg","genre_ids":[28,27,53],"id":1096197,"original_language":"en","original_title":"No Way Up","overview":"Characters from different backgrounds are thrown together when the plane they're travelling on crashes into the Pacific Ocean. A nightmare fight for survival ensues with the air supply running out and dangers creeping in from all sides.","popularity":1532.906,"poster_path":"/hu40Uxp9WtpL34jv3zyWLb5zEVY.jpg","release_date":"2024-01-18","title":"No Way Up","video":false,"vote_average":6.489,"vote_count":498},{"adult":false,"backdrop_path":"/qrGtVFxaD8c7et0jUtaYhyTzzPg.jpg","genre_ids":[28,878,12],"id":823464,"original_language":"en","original_title":"Godzilla x Kong: The New Empire","overview":"Following their explosive showdown, Godzilla and Kong must reunite against a colossal undiscovered threat hidden within our world, challenging their very existence – and our own.","popularity":1611.66,"poster_
# ...

# %%
#ahora paso esta información a un dataframe: 

import requests
import pandas as pd

url = "https://api.themoviedb.org/3/discover/movie?include_adult=false&include_video=false&language=en-US&page=1&sort_by=popularity.desc"

headers = {
    "accept": "application/json",
    "Authorization": ""
}

response = requests.get(url, headers=headers)

#verifico si sale bien
if response.status_code == 200:
    data = response.json()  #respuesta en formato JSON a un diccionario Python
    #extraigo lista de resultados
    results = data.get('results', [])
    #convierto la lista de resultados en un df de pandas
    df = pd.DataFrame(results)
    #imprimo
    print(df)
else:
    print("Error en la solicitud:", response.status_code)
# Out:
#     adult                     backdrop_path                genre_ids       id  \
# 0   False  /4woSOUD0equAYzvwhWBHIJDCM88.jpg             [28, 27, 53]  1096197
# 1   False  /qrGtVFxaD8c7et0jUtaYhyTzzPg.jpg            [28, 878, 12]   823464
# 2   False   /FUnAVgaTs5xZWXcVzPJNxd9qGA.jpg            [878, 28, 18]   934632
# 3   False  /xOMo8BRK7PfcJv9JCnx7s5hj0PX.jpg                [878, 12]   693134
# 4   False  /1XDDXPXGiI8id7MrUxK36ke7gkX.jpg  [16, 28, 10751, 35, 14]  1011985
# 5   False  /jnE1GA7cGEfv5DJBoU2t4bZHaP4.jpg                [28, 878]  1094844
# 6   False  /5Eip60UDiPLASyKjmHPMruggTc4.jpg           [27, 9648, 53]  1041613
# 7   False  /ilK1JRbMjo4sMJtNKLOKnqRf1RH.jpg          [10752, 28, 36]   976906
# 8   False  /qnVm19Vu2Sc14LoEj82pmqAYr3p.jpg             [12, 28, 18]   845111
# 9   False  /vTlK3chwsEToSoQJYUcJaHlNhIf.jpg                 [18, 12]   618588
# 10  False  /fUC5VsQcU3m6zmYMD96R7RqPuMn.jpg             [28, 80, 53]  1105407
# ...

# %%
df.head()
# Out:
#    adult                     backdrop_path                genre_ids       id  \
# 0  False  /4woSOUD0equAYzvwhWBHIJDCM88.jpg             [28, 27, 53]  1096197
# 1  False  /qrGtVFxaD8c7et0jUtaYhyTzzPg.jpg            [28, 878, 12]   823464
# 2  False   /FUnAVgaTs5xZWXcVzPJNxd9qGA.jpg            [878, 28, 18]   934632
# 3  False  /xOMo8BRK7PfcJv9JCnx7s5hj0PX.jpg                [878, 12]   693134
# 4  False  /1XDDXPXGiI8id7MrUxK36ke7gkX.jpg  [16, 28, 10751, 35, 14]  1011985
#
#   original_language                        original_title  \
# 0                en                             No Way Up
# 1                en       Godzilla x Kong: The New Empire
# 2                en  Rebel Moon - Part Two: The Scargiver
# 3                en                        Dune: Part Two
# 4                en                       Kung Fu Panda 4
#
#                                             overview  popularity  \
# 0  Characters from different backgrounds are thro...    1532.906
# ...

# %%
df.count()
# Out:
# adult                20
# backdrop_path        20
# genre_ids            20
# id                   20
# original_language    20
# original_title       20
# overview             20
# popularity           20
# poster_path          20
# release_date         20
# title                20
# video                20
# vote_average         20
# vote_count           20
# dtype: int64

# %% [markdown]
# PELIS AÑO 2022:

# %%
import requests
import pandas as pd

base_url = "https://api.themoviedb.org/3/discover/movie"
params = {
    "include_adult": "false",
    "include_video": "false",
    "language": "en-US",
    "sort_by": "popularity.desc",
    "page": 1,  
    "year": 2022
}

headers = {
    "accept": "application/json",
    "Authorization": "Bearer 1YiI6IjY1ZjZhZmQzNjY0NjlhMDE3ZTdhNTkyNSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.A5VdDbZhVZjV5J6iUvEWiF6WauWFOxzIK5H7Xbvc6Hc"
}

all_results = []  

while True:
    response = requests.get(base_url, headers=headers, params=params)

    if response.status_code == 200:
        data = response.json()  
        results = data.get('results', [])  
        all_results.extend(results)  
        total_pages = data.get('total_pages')  
        params['page'] += 1 

        if params['page'] > total_pages:  
            break
    else:
        print("Error en la solicitud:", response.status_code)
        break

df2022 = pd.DataFrame(all_results)
print(df2022)
# Out:
# Error en la solicitud: 400
#       adult                     backdrop_path          genre_ids       id  \
# 0     False  /ilK1JRbMjo4sMJtNKLOKnqRf1RH.jpg    [10752, 28, 36]   976906
# 1     False  /7ZP8HtgOIDaBs12krXgUIygqEsy.jpg  [878, 28, 14, 12]   601796
# 2     False  /dcnSWFCtk4b2aIzkhq6IDbzoIf1.jpg           [28, 35]   942047
# 3     False  /lzWHmYdfeFiMIY4JaMmtR7GEli3.jpg          [878, 12]   438631
# 4     False  /atPlFdUrQl2U9MtUwujrrjnQHBA.jpg   [28, 80, 18, 53]   654739
# ...     ...                               ...                ...      ...
# 9995  False  /mAx5aQFpvoZcLT7JrVmDfevH2Cs.jpg               [18]   940849
# 9996  False                              None                 []   933803
# 9997  False  /rgvI9BRtJtKLrYxl5jJ2wbpYhzX.jpg    [18, 10749, 53]   796155
# 9998  False  /g9eveG1Hi0qVXnCJAT7PGVL1Wx4.jpg               [28]    74605
# 9999  False                              None                 []  1065151
#
# ...

# %% [markdown]
# PELIS 2021

# %%
import requests
import pandas as pd

base_url = "https://api.themoviedb.org/3/discover/movie"
params = {
    "include_adult": "false",
    "include_video": "false",
    "language": "en-US",
    "sort_by": "popularity.desc",
    "page": 1,  
    "year": 2021  
}

headers = {
    "accept": "application/json",
    "Authorization": "Bearer eyJh1YiI6IjY1ZjZhZmyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.A5VdDbZhVZjV5J6iUvEWiF6WauWFOxzIK5H7Xbvc6Hc"
}

all_results = []  

while True:
    response = requests.get(base_url, headers=headers, params=params)

    if response.status_code == 200:
        data = response.json()  
        results = data.get('results', [])  # Indentación corregida
        all_results.extend(results)  
        total_pages = data.get('total_pages')  
        params['page'] += 1 

        if params['page'] > total_pages:  
            break
    else:
        print("Error en la solicitud:", response.status_code)
        break

df2021 = pd.DataFrame(all_results)
print(df2021)
# Out:
# Error en la solicitud: 400
#       adult                     backdrop_path         genre_ids       id  \
# 0     False  /lzWHmYdfeFiMIY4JaMmtR7GEli3.jpg         [878, 12]   438631
# 1     False  /atPlFdUrQl2U9MtUwujrrjnQHBA.jpg  [28, 80, 18, 53]   654739
# 2     False  /en971MEXui9diirXlogOrPKmsEn.jpg      [28, 12, 35]   293660
# 3     False  /3RWsSQlqzRjsuqSRmoyggy74UA7.jpg      [28, 14, 35]    43074
# 4     False  /yY76zq9XSuJ4nWyPDuwkdV7Wt0c.jpg     [28, 53, 878]   577922
# ...     ...                               ...               ...      ...
# 9995  False                              None              [27]  1144528
# 9996  False  /c9fbOEI6kJw5Eq8NHG2qR5VG70A.jpg                []   934835
# 9997  False  /swaI8REF35bEK8LJtUS22nOHaiZ.jpg          [35, 99]   892051
# 9998  False  /5Nx7qfVpRGeOPE542WZMghTVpfH.jpg              [18]   876674
# 9999  False  /uOIgvDMJ15zofF8bb40wsZpNyk1.jpg              [35]    43206
#
#      original_language        original_title  \
# ...

# %% [markdown]
# PELIS 2020

# %%
import requests
import pandas as pd

base_url = "https://api.themoviedb.org/3/discover/movie"
params = {
    "include_adult": "false",
    "include_video": "false",
    "language": "en-US",
    "sort_by": "popularity.desc",
    "page": 1,  
    "year": 2020  
}

headers = {
    "accept": "application/json",
    "Authorization": "Bearer I6IjY1ZjZhZmQzNjY0NjlhMDE3ZTdhNTkyNSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.A5VdDbZhVZjV5J6iUvEWiF6WauWFOxzIK5H7Xbvc6Hc"
}

all_results = []  

while True:
    response = requests.get(base_url, headers=headers, params=params)

    if response.status_code == 200:
        data = response.json()  
        results = data.get('results', [])  # Indentación corregida
        all_results.extend(results)  
        total_pages = data.get('total_pages')  
        params['page'] += 1 

        if params['page'] > total_pages:  
            break
    else:
        print("Error en la solicitud:", response.status_code)
        break

df2020 = pd.DataFrame(all_results)
print(df2020)
# Out:
# Error en la solicitud: 400
#       adult                     backdrop_path      genre_ids      id  \
# 0     False  /en971MEXui9diirXlogOrPKmsEn.jpg   [28, 12, 35]  293660
# 1     False  /3RWsSQlqzRjsuqSRmoyggy74UA7.jpg   [28, 14, 35]   43074
# 2     False  /yY76zq9XSuJ4nWyPDuwkdV7Wt0c.jpg  [28, 53, 878]  577922
# 3     False  /n6bUvigpRFqSwmPp1m2YADdbRBc.jpg   [80, 53, 18]  475557
# 4     False  /qAzYK4YPSWDc7aa4R43LcwRIAyb.jpg  [28, 12, 878]  299537
# ...     ...                               ...            ...     ...
# 9995  False                              None           [18]  746288
# 9996  False                              None      [35, 878]  743488
# 9997  False                              None             []  743117
# 9998  False                              None           [18]  742763
# 9999  False                              None           [18]  742519
#
#      original_language        original_title  \
# 0                   en              Deadpool
# ...

# %%
df2020.head()
# Out:
#    adult                     backdrop_path      genre_ids      id  \
# 0  False  /en971MEXui9diirXlogOrPKmsEn.jpg   [28, 12, 35]  293660
# 1  False  /3RWsSQlqzRjsuqSRmoyggy74UA7.jpg   [28, 14, 35]   43074
# 2  False  /yY76zq9XSuJ4nWyPDuwkdV7Wt0c.jpg  [28, 53, 878]  577922
# 3  False  /n6bUvigpRFqSwmPp1m2YADdbRBc.jpg   [80, 53, 18]  475557
# 4  False  /qAzYK4YPSWDc7aa4R43LcwRIAyb.jpg  [28, 12, 878]  299537
#
#   original_language  original_title  \
# 0                en        Deadpool
# 1                en    Ghostbusters
# 2                en           Tenet
# 3                en           Joker
# 4                en  Captain Marvel
#
#                                             overview  popularity  \
# 0  The origin story of former Special Forces oper...     454.956
# 1  Following a ghost invasion of Manhattan, paran...     454.747
# 2  Armed with only one word - Tenet - and fightin...     433.928
# 3  During the 1980s, a failed stand-up comedian i...     445.021
# ...

# %%
import requests
import pandas as pd

base_url = "https://api.themoviedb.org/3/discover/movie"
params = {
    "include_adult": "false",
    "include_video": "false",
    "language": "en-US",
    "sort_by": "popularity.desc",
    "page": 1,  
    "year": 2019 
}

headers = {
    "accept": "application/json",
    "Authorization": "
all_results = []  

while True:
    response = requests.get(base_url, headers=headers, params=params)

    if response.status_code == 200:
        data = response.json()  
        results = data.get('results', [])  # Indentación corregida
        all_results.extend(results)  
        total_pages = data.get('total_pages')  
        params['page'] += 1 

        if params['page'] > total_pages:  
            break
    else:
        print("Error en la solicitud:", response.status_code)
        break

df2019 = pd.DataFrame(all_results)
print(df2019)
# Out:
# Error en la solicitud: 400
#       adult                     backdrop_path       genre_ids       id  \
# 0     False  /n6bUvigpRFqSwmPp1m2YADdbRBc.jpg    [80, 53, 18]   475557
# 1     False  /qAzYK4YPSWDc7aa4R43LcwRIAyb.jpg   [28, 12, 878]   299537
# 2     False  /9X7YweCJw3q8Mcf6GadxReFEksM.jpg   [28, 18, 878]   263115
# 3     False  /8K9qHeM6G6QjQN0C5XKFGvK5lzM.jpg       [28, 878]      603
# 4     False  /hdHIjZxq3SWFqpAz4NFhdbud0iz.jpg       [27, 878]      348
# ...     ...                               ...             ...      ...
# 9995  False                              None              []   608098
# 9996  False  /rgHhV67uLbQzZ7dbUuB89CiZrhp.jpg            [99]   391719
# 9997  False  /8RVQ3QeSej8tfX4HhPC3I1BkhzD.jpg  [80, 9648, 53]   674207
# 9998  False                              None            [18]  1277580
# 9999  False                              None            [35]   700133
#
#      original_language                                 original_title  \
# ...

# %%
import requests
import pandas as pd

base_url = "https://api.themoviedb.org/3/discover/movie"
params = {
    "include_adult": "false",
    "include_video": "false",
    "language": "en-US",
    "sort_by": "popularity.desc",
    "page": 1,  
    "year": 2018 
}

headers = {
    "accept": "application/json",
    "Authorization": "BnN1YiI6IjY1ZjZhZmQzNjY0NjlhMDE3ZTdhNTkyNSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.A5VdDbZhVZjV5J6iUvEWiF6WauWFOxzIK5H7Xbvc6Hc"
}

all_results = []  

while True:
    response = requests.get(base_url, headers=headers, params=params)

    if response.status_code == 200:
        data = response.json()  
        results = data.get('results', [])  # Indentación corregida
        all_results.extend(results)  
        total_pages = data.get('total_pages')  
        params['page'] += 1 

        if params['page'] > total_pages:  
            break
    else:
        print("Error en la solicitud:", response.status_code)
        break

df2018 = pd.DataFrame(all_results)
print(df2018)
# Out:
# Error en la solicitud: 400
#       adult                     backdrop_path      genre_ids      id  \
# 0     False  /en971MEXui9diirXlogOrPKmsEn.jpg   [28, 12, 35]  293660
# 1     False  /6iUNJZymJBMXXriQyFZfLAKnjO6.jpg   [28, 12, 14]  297762
# 2     False  /kaIfm5ryEOwYg8mLbq8HkPuM1Fo.jpg  [28, 12, 878]  284053
# 3     False  /9X7YweCJw3q8Mcf6GadxReFEksM.jpg  [28, 18, 878]  263115
# 4     False  /8K9qHeM6G6QjQN0C5XKFGvK5lzM.jpg      [28, 878]     603
# ...     ...                               ...            ...     ...
# 9995  False  /4PsSs6qSeR2UTM0IPgzKNLu4WYJ.jpg    [10751, 35]  494642
# 9996  False                              None             []  713927
# 9997  False  /oNzQUAerCEtzS5FYPOoMTxgpauv.jpg           [18]  837765
# 9998  False  /csTScGuwj1vDCVKkGVxp59mTiwp.jpg  [878, 18, 35]  607886
# 9999  False  /7vdQ7b8WwcwRDXMf2EASZGYLM5t.jpg        [10402]  583886
#
#      original_language   original_title  \
# 0                   en         Deadpool
# ...

# %%
import requests
import pandas as pd

base_url = "https://api.themoviedb.org/3/discover/movie"
params = {
    "include_adult": "false",
    "include_video": "false",
    "language": "en-US",
    "sort_by": "popularity.desc",
    "page": 1,  
    "year": 2017 
}

headers = {
    "accept": "application/json",
    "Authorization": "Bearer e
}

all_results = []  

while True:
    response = requests.get(base_url, headers=headers, params=params)

    if response.status_code == 200:
        data = response.json()  
        results = data.get('results', [])  # Indentación corregida
        all_results.extend(results)  
        total_pages = data.get('total_pages')  
        params['page'] += 1 

        if params['page'] > total_pages:  
            break
    else:
        print("Error en la solicitud:", response.status_code)
        break

df2017 = pd.DataFrame(all_results)
print(df2017)
# Out:
# Error en la solicitud: 400
#       adult                     backdrop_path            genre_ids      id  \
# 0     False  /3RWsSQlqzRjsuqSRmoyggy74UA7.jpg         [28, 14, 35]   43074
# 1     False  /6iUNJZymJBMXXriQyFZfLAKnjO6.jpg         [28, 12, 14]  297762
# 2     False  /kaIfm5ryEOwYg8mLbq8HkPuM1Fo.jpg        [28, 12, 878]  284053
# 3     False  /9X7YweCJw3q8Mcf6GadxReFEksM.jpg        [28, 18, 878]  263115
# 4     False  /xJHokMbljvjADYdit5fK5VQsXEG.jpg        [12, 18, 878]  157336
# ...     ...                               ...                  ...     ...
# 9995  False  /cI1245MAkh7wVsR1N1VHeOYa3Kr.jpg                 [35]  472225
# 9996  False  /z6JraWUlKop278ufanjBCpJu7Gr.jpg                 [18]  417264
# 9997  False  /oPzqqWEIgKfEds8hjMByUL6uS09.jpg  [16, 10751, 14, 35]  999332
# 9998  False                              None                 [99]  568834
# 9999  False                              None                 [99]  558052
#
# ...

# %%
import pandas as pd

#combino todos los DF para tener 1 final
df_años = pd.concat([df2017, df2018, df2019, df2020, df2021, df], ignore_index=True)

df_años.head()
# Out:
#    adult                     backdrop_path      genre_ids      id  \
# 0  False  /3RWsSQlqzRjsuqSRmoyggy74UA7.jpg   [28, 14, 35]   43074
# 1  False  /6iUNJZymJBMXXriQyFZfLAKnjO6.jpg   [28, 12, 14]  297762
# 2  False  /kaIfm5ryEOwYg8mLbq8HkPuM1Fo.jpg  [28, 12, 878]  284053
# 3  False  /9X7YweCJw3q8Mcf6GadxReFEksM.jpg  [28, 18, 878]  263115
# 4  False  /xJHokMbljvjADYdit5fK5VQsXEG.jpg  [12, 18, 878]  157336
#
#   original_language  original_title  \
# 0                en    Ghostbusters
# 1                en    Wonder Woman
# 2                en  Thor: Ragnarok
# 3                en           Logan
# 4                en    Interstellar
#
#                                             overview  popularity  \
# 0  Following a ghost invasion of Manhattan, paran...     454.747
# 1  An Amazon princess comes to the world of Man i...     393.794
# 2  Thor is imprisoned on the other side of the un...     393.367
# 3  In the near future, a weary Logan cares for an...     412.050
# ...

# %%
df_años.tail()
# Out:
#        adult                     backdrop_path                genre_ids  \
# 50015  False  /2KGxQFV9Wp1MshPBf8BuqWUgVAz.jpg  [16, 28, 12, 35, 10751]
# 50016  False  /tBmJCH9llj1Q9jDOS7vGWnl7GVj.jpg            [16, 878, 28]
# 50017  False  /qekky2LbtT1wtbD5MDgQvjfZQ24.jpg                 [28, 53]
# 50018  False  /uv2twFGMk2qBdyJBJAVcrpRtSa9.jpg          [10752, 28, 18]
# 50019  False  /9wJO4MBzkqgUZemLTGEsgUbYyP6.jpg          [878, 9648, 53]
#
#             id original_language  \
# 50015   940551                en
# 50016  1209288                en
# 50017   984324                fr
# 50018   929590                en
# 50019   720321                en
#
#                                           original_title  \
# 50015                                          Migration
# 50016  Justice League: Crisis on Infinite Earths Part...
# 50017                              Le salaire de la peur
# 50018                                          Civil War
# ...

# %%
import pandas as pd

#para no ejecutarlo todo cada vez que entro de nuevo, lo paso a un CSV
df_años.to_csv('df_años.csv', index=False)

# %%
#leo el CSV
df2 = pd.read_csv('df_años - copia.csv')

# %%
df2.head()
# Out:
#    adult                     backdrop_path      genre_ids      id  \
# 0  False  /3RWsSQlqzRjsuqSRmoyggy74UA7.jpg   [28, 14, 35]   43074
# 1  False  /6iUNJZymJBMXXriQyFZfLAKnjO6.jpg   [28, 12, 14]  297762
# 2  False  /kaIfm5ryEOwYg8mLbq8HkPuM1Fo.jpg  [28, 12, 878]  284053
# 3  False  /9X7YweCJw3q8Mcf6GadxReFEksM.jpg  [28, 18, 878]  263115
# 4  False  /xJHokMbljvjADYdit5fK5VQsXEG.jpg  [12, 18, 878]  157336
#
#   original_language  original_title  \
# 0                en    Ghostbusters
# 1                en    Wonder Woman
# 2                en  Thor: Ragnarok
# 3                en           Logan
# 4                en    Interstellar
#
#                                             overview  popularity  \
# 0  Following a ghost invasion of Manhattan, paran...     454.747
# 1  An Amazon princess comes to the world of Man i...     393.794
# 2  Thor is imprisoned on the other side of the un...     393.367
# 3  In the near future, a weary Logan cares for an...     412.050
# ...

# %% [markdown]
# HASTA AQUÍ CÓDIGO EJECUTADO Y GUARDADO EN UN CSV

# %%
longitud_maxima = df2['genre_ids'].apply(len).max()

print("Longitud máxima de la lista más larga:", longitud_maxima)
# Out:
# Longitud máxima de la lista más larga: 40

# %%
fila_lista_mas_larga = df.loc[df2['genre_ids'].apply(len).idxmax()]

lista_mas_larga = fila_lista_mas_larga['genre_ids']

print("La lista más larga es:", lista_mas_larga)
# Out:
# La lista más larga es: [10751, 10402, 14, 10770, 12, 28, 10749]

# %%
df_separado = df2['genre_ids'].str.split(',').apply(lambda x: [e.strip('[]') for e in x]).apply(pd.Series)

#le pongo nombre a las columnas
column_names = ['columna{}'.format(i+1) for i in range(len(df_separado.columns))]
df_separado.columns = column_names

df2 = pd.concat([df, df_separado], axis=1)

df2
# Out:
#        adult                     backdrop_path                genre_ids  \
# 0      False  /3RWsSQlqzRjsuqSRmoyggy74UA7.jpg             [28, 14, 35]
# 1      False  /6iUNJZymJBMXXriQyFZfLAKnjO6.jpg             [28, 12, 14]
# 2      False  /kaIfm5ryEOwYg8mLbq8HkPuM1Fo.jpg            [28, 12, 878]
# 3      False  /9X7YweCJw3q8Mcf6GadxReFEksM.jpg            [28, 18, 878]
# 4      False  /xJHokMbljvjADYdit5fK5VQsXEG.jpg            [12, 18, 878]
# ...      ...                               ...                      ...
# 50015  False  /2KGxQFV9Wp1MshPBf8BuqWUgVAz.jpg  [16, 28, 12, 35, 10751]
# 50016  False  /tBmJCH9llj1Q9jDOS7vGWnl7GVj.jpg            [16, 878, 28]
# 50017  False  /qekky2LbtT1wtbD5MDgQvjfZQ24.jpg                 [28, 53]
# 50018  False  /uv2twFGMk2qBdyJBJAVcrpRtSa9.jpg          [10752, 28, 18]
# 50019  False  /9wJO4MBzkqgUZemLTGEsgUbYyP6.jpg          [878, 9648, 53]
#
#             id original_language  \
# 0        43074                en
# ...

# %%
#como salen columnas que no quiero, las voy a borrar y me quedo con las buenas
columnas_que_borro = [f'genero{i}' for i in range(2, 10)]
df2.drop(columns=columnas_que_borro, inplace=True)

# %%
#ahora borro la de genero
columnas_que_borro2 = ['genero']

# Eliminar las columnas especificadas
df2.drop(columns=columnas_que_borro2, inplace=True)

# %%
df2
# Out:
#        adult                     backdrop_path                genre_ids  \
# 0      False  /3RWsSQlqzRjsuqSRmoyggy74UA7.jpg             [28, 14, 35]
# 1      False  /6iUNJZymJBMXXriQyFZfLAKnjO6.jpg             [28, 12, 14]
# 2      False  /kaIfm5ryEOwYg8mLbq8HkPuM1Fo.jpg            [28, 12, 878]
# 3      False  /9X7YweCJw3q8Mcf6GadxReFEksM.jpg            [28, 18, 878]
# 4      False  /xJHokMbljvjADYdit5fK5VQsXEG.jpg            [12, 18, 878]
# ...      ...                               ...                      ...
# 50015  False  /2KGxQFV9Wp1MshPBf8BuqWUgVAz.jpg  [16, 28, 12, 35, 10751]
# 50016  False  /tBmJCH9llj1Q9jDOS7vGWnl7GVj.jpg            [16, 878, 28]
# 50017  False  /qekky2LbtT1wtbD5MDgQvjfZQ24.jpg                 [28, 53]
# 50018  False  /uv2twFGMk2qBdyJBJAVcrpRtSa9.jpg          [10752, 28, 18]
# 50019  False  /9wJO4MBzkqgUZemLTGEsgUbYyP6.jpg          [878, 9648, 53]
#
#             id original_language  \
# 0        43074                en
# ...

# %%
import pandas as pd

#para no ejecutarlo todo cada vez que entro de nuevo, lo paso a un CSV
df2.to_csv('df2.csv', index=False)

# %%
df2
# Out:
#        adult                     backdrop_path                genre_ids  \
# 0      False  /3RWsSQlqzRjsuqSRmoyggy74UA7.jpg             [28, 14, 35]
# 1      False  /6iUNJZymJBMXXriQyFZfLAKnjO6.jpg             [28, 12, 14]
# 2      False  /kaIfm5ryEOwYg8mLbq8HkPuM1Fo.jpg            [28, 12, 878]
# 3      False  /9X7YweCJw3q8Mcf6GadxReFEksM.jpg            [28, 18, 878]
# 4      False  /xJHokMbljvjADYdit5fK5VQsXEG.jpg            [12, 18, 878]
# ...      ...                               ...                      ...
# 50015  False  /2KGxQFV9Wp1MshPBf8BuqWUgVAz.jpg  [16, 28, 12, 35, 10751]
# 50016  False  /tBmJCH9llj1Q9jDOS7vGWnl7GVj.jpg            [16, 878, 28]
# 50017  False  /qekky2LbtT1wtbD5MDgQvjfZQ24.jpg                 [28, 53]
# 50018  False  /uv2twFGMk2qBdyJBJAVcrpRtSa9.jpg          [10752, 28, 18]
# 50019  False  /9wJO4MBzkqgUZemLTGEsgUbYyP6.jpg          [878, 9648, 53]
#
#             id original_language  \
# 0        43074                en
# ...

# %% [markdown]
# MAPEAR GENRE_iD CON EL GÉNERO QUE CORRESPONDA

# %%
import requests
import json

url = "https://api.themoviedb.org/3/genre/movie/list?language=en"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.A5VdDbZhVZjV5J6iUvEWiF6WauWFOxzIK5H7Xbvc6Hc"
}

response = requests.get(url, headers=headers)
data = response.json()

# Imprimo los géneros en una lista
print("List of movie genres:")
for genre in data['genres']:
    print(f"- {genre['name']} (ID: {genre['id']})")
# Out:
# List of movie genres:
# - Action (ID: 28)
# - Adventure (ID: 12)
# - Animation (ID: 16)
# - Comedy (ID: 35)
# - Crime (ID: 80)
# - Documentary (ID: 99)
# - Drama (ID: 18)
# - Family (ID: 10751)
# - Fantasy (ID: 14)
# - History (ID: 36)
# - Horror (ID: 27)
# - Music (ID: 10402)
# - Mystery (ID: 9648)
# - Romance (ID: 10749)
# - Science Fiction (ID: 878)
# - TV Movie (ID: 10770)
# - Thriller (ID: 53)
# - War (ID: 10752)
# - Western (ID: 37)

# %%
df.dtypes
# Out:
# adult                   bool
# backdrop_path         object
# genre_ids             object
# id                     int64
# original_language     object
# original_title        object
# overview              object
# popularity           float64
# poster_path           object
# release_date          object
# title                 object
# video                   bool
# vote_average         float64
# vote_count             int64
# columna1              object
# columna2              object
# columna3              object
# columna4              object
# columna5              object
# columna6              object
# columna7              object
# dtype: object

# %%
import pandas as pd

# Suponiendo que tienes un DataFrame llamado df con las columnas columna1, columna2, ..., columna7

# Diccionario de mapeo para cada columna
mapeo_columnas = {
    'columna1': {28: 'Action', 12: 'Adventure', 16: 'Animation', 35: 'Comedy', 80: 'Crime', 99: 'Documentary', 18: 'Drama', 10751: 'Family', 14: 'Fantasy', 36: 'History', 27: 'Horror', 10402: 'Music', 9648: 'Mystery', 10749: 'Romance', 878: 'Science Fiction', 10770: 'TV Movie', 53: 'Thriller', 10752: 'War', 37: 'Western'},
    'columna2': {28: 'Action', 12: 'Adventure', 16: 'Animation', 35: 'Comedy', 80: 'Crime', 99: 'Documentary', 18: 'Drama', 10751: 'Family', 14: 'Fantasy', 36: 'History', 27: 'Horror', 10402: 'Music', 9648: 'Mystery', 10749: 'Romance', 878: 'Science Fiction', 10770: 'TV Movie', 53: 'Thriller', 10752: 'War', 37: 'Western'},
    'columna3': {28: 'Action', 12: 'Adventure', 16: 'Animation', 35: 'Comedy', 80: 'Crime', 99: 'Documentary', 18: 'Drama', 10751: 'Family', 14: 'Fantasy', 36: 'History', 27: 'Horror', 10402: 'Music', 9648: 'Mystery', 10749: 'Romance', 878: 'Science Fiction', 10770: 'TV Movie', 53: 'Thriller', 10752: 'War', 37: 'Western'}, 
    'columna4': {28: 'Action', 12: 'Adventure', 16: 'Animation', 35: 'Comedy', 80: 'Crime', 99: 'Documentary', 18: 'Drama', 10751: 'Family', 14: 'Fantasy', 36: 'History', 27: 'Horror', 10402: 'Music', 9648: 'Mystery', 10749: 'Romance', 878: 'Science Fiction', 10770: 'TV Movie', 53: 'Thriller', 10752: 'War', 37: 'Western'}, 
    'columna5': {28: 'Action', 12: 'Adventure', 16: 'Animation', 35: 'Comedy', 80: 'Crime', 99: 'Documentary', 18: 'Drama', 10751: 'Family', 14: 'Fantasy', 36: 'History', 27: 'Horror', 10402: 'Music', 9648: 'Mystery', 10749: 'Romance', 878: 'Science Fiction', 10770: 'TV Movie', 53: 'Thriller', 10752: 'War', 37: 'Western'}, 
    'columna6': {28: 'Action', 12: 'Adventure', 16: 'Animation', 35: 'Comedy', 80: 'Crime', 99: 'Documentary', 18: 'Drama', 10751: 'Family', 14: 'Fantasy', 36: 'History', 27: 'Horror', 10402: 'Music', 9648: 'Mystery', 10749: 'Romance', 878: 'Science Fiction', 10770: 'TV Movie', 53: 'Thriller', 10752: 'War', 37: 'Western'}, 
    'columna7': {28: 'Action', 12: 'Adventure', 16: 'Animation', 35: 'Comedy', 80: 'Crime', 99: 'Documentary', 18: 'Drama', 10751: 'Family', 14: 'Fantasy', 36: 'History', 27: 'Horror', 10402: 'Music', 9648: 'Mystery', 10749: 'Romance', 878: 'Science Fiction', 10770: 'TV Movie', 53: 'Thriller', 10752: 'War', 37: 'Western'}, 
}

# Convertir las columnas a tipo cadena
for columna, mapeo in mapeo_columnas.items():
    df[columna] = df[columna].map(mapeo).fillna("Desconocido")  # Si no hay mapeo, llenamos con "Desconocido"

# %%
df
# Out:
#        adult                     backdrop_path                genre_ids  \
# 0      False  /3RWsSQlqzRjsuqSRmoyggy74UA7.jpg             [28, 14, 35]
# 1      False  /6iUNJZymJBMXXriQyFZfLAKnjO6.jpg             [28, 12, 14]
# 2      False  /kaIfm5ryEOwYg8mLbq8HkPuM1Fo.jpg            [28, 12, 878]
# 3      False  /9X7YweCJw3q8Mcf6GadxReFEksM.jpg            [28, 18, 878]
# 4      False  /xJHokMbljvjADYdit5fK5VQsXEG.jpg            [12, 18, 878]
# ...      ...                               ...                      ...
# 50015  False  /2KGxQFV9Wp1MshPBf8BuqWUgVAz.jpg  [16, 28, 12, 35, 10751]
# 50016  False  /tBmJCH9llj1Q9jDOS7vGWnl7GVj.jpg            [16, 878, 28]
# 50017  False  /qekky2LbtT1wtbD5MDgQvjfZQ24.jpg                 [28, 53]
# 50018  False  /uv2twFGMk2qBdyJBJAVcrpRtSa9.jpg          [10752, 28, 18]
# 50019  False  /9wJO4MBzkqgUZemLTGEsgUbYyP6.jpg          [878, 9648, 53]
#
#             id original_language  \
# 0        43074                en
# ...

# %%
#creo el diccionario con los generos 
genres = {genre['id']: genre['name'] for genre in data['genres']}

# %%
genres
# Out:
# {28: 'Action',
#  12: 'Adventure',
#  16: 'Animation',
#  35: 'Comedy',
#  80: 'Crime',
#  99: 'Documentary',
#  18: 'Drama',
#  10751: 'Family',
#  14: 'Fantasy',
#  36: 'History',
#  27: 'Horror',
#  10402: 'Music',
#  9648: 'Mystery',
#  10749: 'Romance',
#  878: 'Science Fiction',
#  10770: 'TV Movie',
#  53: 'Thriller',
#  10752: 'War',
#  37: 'Western'}

# %%
# Mapear los números de genre_ids con los nombres de los géneros usando replace
df_años['genre_ids'] = df_años['genre_ids'].replace(genres)

# %%
import requests
import json

url = "https://api.themoviedb.org/3/genre/movie/list?language=en"

headers = {
    "accept": "application/json",
    "Authorization": "BearerxzIK5H7Xbvc6Hc"
}

response = requests.get(url, headers=headers)
data = response.json()
if 'genres' not in data:
    print("Error: No se encontró la clave 'genres' en la respuesta.")
    exit()

# Crear el diccionario con los géneros
genres = {genre['id']: genre['name'] for genre in data['genres']}

df_años = pd.DataFrame(data_df)

# Convertir genre_ids a tipo str y luego usar replace
df_años['genre_ids'] = df_años['genre_ids'].astype(str).replace(genres)

print(df_años)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[25], line 20
#      17 # Crear el diccionario con los géneros
#      18 genres = {genre['id']: genre['name'] for genre in data['genres']}
# ---> 20 df_años = pd.DataFrame(data_df)
#      22 # Convertir genre_ids a tipo str y luego usar replace
#      23 df_años['genre_ids'] = df_años['genre_ids'].astype(str).replace(genres)
#
# NameError: name 'data_df' is not defined

# %%
import requests
import json
import pandas as pd


# Verificar si 'genres' está en la respuesta
if 'genres' not in genres:
    print("Error: No se encontró la clave 'genres' en la respuesta.")
    exit()

# Crear el diccionario con los géneros
genres = {genre['id']: genre['name'] for genre in data['genres']}

# Convertir genre_ids a tipo str y luego usar replace
df_años['genre_ids'] = df_años['genre_ids'].astype(str).replace(genres)

print(df_años)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 7
#       3 import pandas as pd
#       6 # Verificar si 'genres' está en la respuesta
# ----> 7 if 'genres' not in genres:
#       8     print("Error: No se encontró la clave 'genres' en la respuesta.")
#       9     exit()
#
# NameError: name 'genres' is not defined

# %%
df_años.tail()
# Out:
#    movie_id genre_ids
# 0         1        28
# 1         2        35
# 2         3        18

# %%
# Check if column is numerical
if pd.api.types.is_numeric_dtype(df_años['genre_ids']):
  # Replace values and potentially drop the 'genre_ids' column
  df_años['genre_names'] = df_años['genre_ids'].replace(genres, method='mapping')
  if not pd.api.types.is_string_dtype(df_años['genre_names']):
    df_años.drop('genre_ids', axis=1, inplace=True)

print(df_años)
# Out:
#        adult                     backdrop_path                    genre_ids  \
# 0      False  /kaIfm5ryEOwYg8mLbq8HkPuM1Fo.jpg                [28, 12, 878]
# 1      False  /xJHokMbljvjADYdit5fK5VQsXEG.jpg                [12, 18, 878]
# 2      False  /zCjZfevPFBbOh2SAx2syIBHSqEI.jpg                [28, 18, 878]
# 3      False  /mDfJG3LC3Dqb67AZ52x3Z0jU0uB.jpg                [12, 28, 878]
# 4      False  /mVr0UiqyltcfqxbAUcLl9zWL8ah.jpg                    [878, 18]
# ...      ...                               ...                          ...
# 49995  False                              None                 [Documental]
# 49996  False  /7SNMu0eBx6uFciONIlUVjFniPkl.jpg  [Fantasía, Aventura, Drama]
# 49997  False  /aYgKXzcngL7TKs6p9NhjYfYJK1G.jpg                      [Drama]
# 49998  False  /gObMmG8I701bhO2xhV751LirlKv.jpg                    [Comedia]
# 49999  False  /8mGwBZm61PipyMbGIYFkjaNPbl9.jpg                      [Drama]
#
#             id original_language  \
# ...

# %%
import pandas as pd

# Save DataFrame to CSV
df.to_csv('movies_with_genre_names.csv', index=False)

# %%
df_final = pd.read_csv('movies_with_genre_names.csv')

# %%
df_final.head()
# Out:
#    adult                     backdrop_path          genre_ids      id  \
# 0  False  /7ZP8HtgOIDaBs12krXgUIygqEsy.jpg  [878, 28, 14, 12]  601796
# 1  False  /9c0lHTXRqDBxeOToVzRu0GArSne.jpg          [878, 28]  935271
# 2  False  /2c2Osibm2Q1eEJCW8jc98GQhGdc.jpg           [12, 28]  893334
# 3  False  /rKmp0vm6PNaFA0g1bzM70eyWJ6I.jpg               [28]  873972
# 4  False  /lzWHmYdfeFiMIY4JaMmtR7GEli3.jpg          [878, 12]  438631
#
#   original_language                 original_title  \
# 0                ko                        외계+인 1부
# 1                en             After the Pandemic
# 2                en  The Adventures of Maid Marian
# 3                en                        Hunters
# 4                en                           Dune
#
#                                             overview  popularity  \
# 0  Gurus in the late Goryeo dynasty try to obtain...    1805.501
# 1  Set in a post-apocalyptic world where a global...     906.812
# ...
