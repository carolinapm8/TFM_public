# %% [markdown]
# BUDGET

# %%
import pandas as pd

# %%
df = pd.read_csv('df_gender.csv')
df
# Out:
#        adult                     backdrop_path                genre_ids  \
# 0      False  /3RWsSQlqzRjsuqSRmoyggy74UA7.jpg             [28, 14, 35]
# 1      False  /6iUNJZymJBMXXriQyFZfLAKnjO6.jpg             [28, 12, 14]
# 2      False  /kaIfm5ryEOwYg8mLbq8HkPuM1Fo.jpg            [28, 12, 878]
# 3      False  /9X7YweCJw3q8Mcf6GadxReFEksM.jpg            [28, 18, 878]
# 4      False  /xJHokMbljvjADYdit5fK5VQsXEG.jpg            [12, 18, 878]
# ...      ...                               ...                      ...
# 50015  False  /2KGxQFV9Wp1MshPBf8BuqWUgVAz.jpg  [16, 28, 12, 35, 10751]
# 50016  False  /tBmJCH9llj1Q9jDOS7vGWnl7GVj.jpg            [16, 878, 28]
# 50017  False  /qekky2LbtT1wtbD5MDgQvjfZQ24.jpg                 [28, 53]
# 50018  False  /uv2twFGMk2qBdyJBJAVcrpRtSa9.jpg          [10752, 28, 18]
# 50019  False  /9wJO4MBzkqgUZemLTGEsgUbYyP6.jpg          [878, 9648, 53]
#
#             id original_language  \
# 0        43074                en
# ...

# %%
import requests

url = "https://api.themoviedb.org/3/movie/43074?language=en-US"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer i1YiI6IjY1ZjZhZmQzNjY0NjlhMDE3ZTdhNTkyNSIsInNjb3BlcyI6WyJhcGlfcmVhZCJdLCJ2ZXJzaW9uIjoxfQ.A5VdDbZhVZjV5J6iUvEWiF6WauWFOxzIK5H7Xbvc6Hc"
}

response = requests.get(url, headers=headers)

# Verificar si la solicitud fue exitosa
if response.status_code == 200:
    movie_data = response.json()
    budget = movie_data['budget']
    print("El budget de la película es:", budget)
else:
    print("Error al obtener los datos. Código de estado:", response.status_code)
# Out:
# El budget de la película es: 144000000

# %%
import pandas as pd
import requests

# Suponiendo que tienes un DataFrame llamado 'df' con una columna 'id' que contiene los IDs de las películas

url = "https://api.themoviedb.org/3/movie/43074?language=en-US"

headers = {
    "accept": "application/json",
    "Authorization": "Bearer aW9uIjoxfQ.A5VdDbZhVZjV5J6iUvEWiF6WauWFOxzIK5H7Xbvc6Hc"
}

response = requests.get(url, headers=headers)

# Verificar si la solicitud fue exitosa
if response.status_code == 200:
    movie_data = response.json()
    budget = movie_data['budget']
    print("El budget de la película es:", budget)
    
    # Actualizar el DataFrame con el valor del budget correspondiente al ID de la película
    movie_id = movie_data['id']
    df.loc[df['id'] == movie_id, 'budget'] = budget
    
    print("El budget se ha actualizado en el DataFrame.")
else:
    print("Error al obtener los datos. Código de estado:", response.status_code)


df
# Out:
# El budget de la película es: 144000000
# El budget se ha actualizado en el DataFrame.
#        adult                     backdrop_path                genre_ids  \
# 0      False  /3RWsSQlqzRjsuqSRmoyggy74UA7.jpg             [28, 14, 35]
# 1      False  /6iUNJZymJBMXXriQyFZfLAKnjO6.jpg             [28, 12, 14]
# 2      False  /kaIfm5ryEOwYg8mLbq8HkPuM1Fo.jpg            [28, 12, 878]
# 3      False  /9X7YweCJw3q8Mcf6GadxReFEksM.jpg            [28, 18, 878]
# 4      False  /xJHokMbljvjADYdit5fK5VQsXEG.jpg            [12, 18, 878]
# ...      ...                               ...                      ...
# 50015  False  /2KGxQFV9Wp1MshPBf8BuqWUgVAz.jpg  [16, 28, 12, 35, 10751]
# 50016  False  /tBmJCH9llj1Q9jDOS7vGWnl7GVj.jpg            [16, 878, 28]
# 50017  False  /qekky2LbtT1wtbD5MDgQvjfZQ24.jpg                 [28, 53]
# 50018  False  /uv2twFGMk2qBdyJBJAVcrpRtSa9.jpg          [10752, 28, 18]
# 50019  False  /9wJO4MBzkqgUZemLTGEsgUbYyP6.jpg          [878, 9648, 53]
#
# ...

# %%
import pandas as pd
import requests

# Crear una función para obtener el budget de una película dado su ID
def get_movie_budget(movie_id):
    url = f"https://api.themoviedb.org/3/movie/{movie_id}?language=en-US"

    headers = {
        "accept": "application/json",
        "Authorization": "BearerN1YW9uIjoxfQ.A5VdDbZhVZjV5J6iUvEWiF6WauWFOxzIK5H7Xbvc6Hc"
    }

    response = requests.get(url, headers=headers)

    if response.status_code == 200:
        movie_data = response.json()
        budget = movie_data['budget']
        return budget
    else:
        print(f"Error al obtener los datos para la película con ID {movie_id}. Código de estado:", response.status_code)
        return None

# Iterar sobre las filas del DataFrame para obtener y actualizar el budget de cada película
for index, row in df.iterrows():
    movie_id = row['id']
    print(f"Obteniendo información para la película con ID {movie_id}...")

    # Obtener el budget de la película
    budget = get_movie_budget(movie_id)

    if budget is not None:
        # Actualizar el DataFrame con el valor del budget correspondiente al ID de la película
        df.at[index, 'budget'] = budget
        print(f"Budget actualizado para la película con ID {movie_id}: {budget}")
    else:
        print(f"No se pudo obtener el budget para la película con ID {movie_id}")

# Al finalizar, mostrar un mensaje indicando que el proceso ha sido completado
print("Proceso completado.")
# Out:
# Obteniendo información para la película con ID 43074...
# Budget actualizado para la película con ID 43074: 144000000
# Obteniendo información para la película con ID 297762...
# Budget actualizado para la película con ID 297762: 149000000
# Obteniendo información para la película con ID 284053...
# Budget actualizado para la película con ID 284053: 180000000
# Obteniendo información para la película con ID 263115...
# Budget actualizado para la película con ID 263115: 97000000
# Obteniendo información para la película con ID 157336...
# Budget actualizado para la película con ID 157336: 165000000
# Obteniendo información para la película con ID 16320...
# Budget actualizado para la película con ID 16320: 39000000
# Obteniendo información para la película con ID 348...
# Budget actualizado para la película con ID 348: 11000000
# Obteniendo información para la película con ID 62...
# Budget actualizado para la película con ID 62: 12000000
# ...

# %%
df
# Out:
#        adult                     backdrop_path                genre_ids  \
# 0      False  /3RWsSQlqzRjsuqSRmoyggy74UA7.jpg             [28, 14, 35]
# 1      False  /6iUNJZymJBMXXriQyFZfLAKnjO6.jpg             [28, 12, 14]
# 2      False  /kaIfm5ryEOwYg8mLbq8HkPuM1Fo.jpg            [28, 12, 878]
# 3      False  /9X7YweCJw3q8Mcf6GadxReFEksM.jpg            [28, 18, 878]
# 4      False  /xJHokMbljvjADYdit5fK5VQsXEG.jpg            [12, 18, 878]
# ...      ...                               ...                      ...
# 50015  False  /2KGxQFV9Wp1MshPBf8BuqWUgVAz.jpg  [16, 28, 12, 35, 10751]
# 50016  False  /tBmJCH9llj1Q9jDOS7vGWnl7GVj.jpg            [16, 878, 28]
# 50017  False  /qekky2LbtT1wtbD5MDgQvjfZQ24.jpg                 [28, 53]
# 50018  False  /uv2twFGMk2qBdyJBJAVcrpRtSa9.jpg          [10752, 28, 18]
# 50019  False  /9wJO4MBzkqgUZemLTGEsgUbYyP6.jpg          [878, 9648, 53]
#
#             id original_language  \
# 0        43074                en
# ...

# %%
import pandas as pd
import requests
import os

def get_movie_budget(movie_id):
    url = f"https://api.themoviedb.org/3/movie/{movie_id}?language=en-US"
    headers = {
        "accept": "application/json",
        "Authorization": "Bearer eK5H7Xbvc6Hc"
    }
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        movie_data = response.json()
        budget = movie_data['budget']
        return budget
    else:
        print(f"Error al obtener los datos para la película con ID {movie_id}. Código de estado:", response.status_code)
        return None

nombre_base_csv = 'data_'

contador_filas_total = 0

archivos_csv_guardados = [archivo for archivo in os.listdir() if archivo.startswith(nombre_base_csv)]

if archivos_csv_guardados:
    archivo_csv_ultimo = max(archivos_csv_guardados)
    df_anterior = pd.read_csv(archivo_csv_ultimo)
    contador_filas_total = len(df_anterior)
    print(f"Cargando el último archivo CSV guardado: {archivo_csv_ultimo}. Continuando desde la fila {contador_filas_total + 1}.")

# Iterar sobre las filas restantes del DataFrame original para obtener y actualizar el budget de cada película
for index, row in df.iloc[contador_filas_total:].iterrows():
    movie_id = row['id']
    print(f"Obteniendo información para la película con ID {movie_id}...")

    # Obtener el budget de la película
    budget = get_movie_budget(movie_id)

    if budget is not None and budget != 0:
        # Actualizar el DataFrame con el valor del budget correspondiente al ID de la película
        df.at[index, 'budget'] = budget
        print(f"Budget actualizado para la película con ID {movie_id}: {budget}")
    else:
        print(f"No se pudo obtener el budget o el budget es 0 para la película con ID {movie_id}")
        # Añadir la columna 'budget' con valor 0 al DataFrame en caso de que no se pueda obtener el budget o sea 0
        df.at[index, 'budget'] = 0

    # Incrementar el contador de filas total
    contador_filas_total += 1

    # Verificar si el contador de filas total es divisible por 5000 para guardar en un archivo CSV
    if contador_filas_total % 5000 == 0:
        # Guardar el DataFrame en un nuevo archivo CSV
        nombre_archivo_csv = f"{nombre_base_csv}{contador_filas_total}.csv"
        df.to_csv(nombre_archivo_csv, index=False)
        print(f"Se ha guardado el DataFrame en '{nombre_archivo_csv}'")

# Al finalizar, mostrar un mensaje indicando que el proceso ha sido completado
print("Proceso completado.")
# Out:
# Obteniendo información para la película con ID 43074...
# Budget actualizado para la película con ID 43074: 144000000
# Obteniendo información para la película con ID 297762...
# Budget actualizado para la película con ID 297762: 149000000
# Obteniendo información para la película con ID 284053...
# Budget actualizado para la película con ID 284053: 180000000
# Obteniendo información para la película con ID 263115...
# Budget actualizado para la película con ID 263115: 97000000
# Obteniendo información para la película con ID 157336...
# Budget actualizado para la película con ID 157336: 165000000
# Obteniendo información para la película con ID 16320...
# Budget actualizado para la película con ID 16320: 39000000
# Obteniendo información para la película con ID 348...
# Budget actualizado para la película con ID 348: 11000000
# Obteniendo información para la película con ID 62...
# Budget actualizado para la película con ID 62: 12000000
# ...

# %%
import pandas as pd
import requests
import os

def get_movie_budget(movie_id):
    url = f"https://api.themoviedb.org/3/movie/{movie_id}?language=en-US"
    headers = {
        "accept": "application/json",
        "Authorization": "Bearer e5H7Xbvc6Hc"
    }
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        movie_data = response.json()
        budget = movie_data['budget']
        return budget
    else:
        print(f"Error al obtener los datos para la película con ID {movie_id}. Código de estado:", response.status_code)
        return None

nombre_base_csv = 'data2_'

contador_filas_total = 25500

archivos_csv_guardados = [archivo for archivo in os.listdir() if archivo.startswith(nombre_base_csv)]

if archivos_csv_guardados:
    archivo_csv_ultimo = max(archivos_csv_guardados)
    df_anterior = pd.read_csv(archivo_csv_ultimo)
    contador_filas_total = len(df_anterior)
    print(f"Cargando el último archivo CSV guardado: {archivo_csv_ultimo}. Continuando desde la fila {contador_filas_total + 1}.")

# Iterar sobre las filas restantes del DataFrame original para obtener y actualizar el budget de cada película
for index, row in df.iloc[contador_filas_total:].iterrows():
    movie_id = row['id']
    print(f"Obteniendo información para la película con ID {movie_id}...")

    # Obtener el budget de la película
    budget = get_movie_budget(movie_id)

    if budget is not None and budget != 0:
        # Actualizar el DataFrame con el valor del budget correspondiente al ID de la película
        df.at[index, 'budget'] = budget
        print(f"Budget actualizado para la película con ID {movie_id}: {budget}")
    else:
        print(f"No se pudo obtener el budget o el budget es 0 para la película con ID {movie_id}")
        # Añadir la columna 'budget' con valor 0 al DataFrame en caso de que no se pueda obtener el budget o sea 0
        df.at[index, 'budget'] = 0

    # Incrementar el contador de filas total
    contador_filas_total += 1

    # Verificar si el contador de filas total es divisible por 5000 para guardar en un archivo CSV
    if contador_filas_total % 2500 == 0:
        # Guardar el DataFrame en un nuevo archivo CSV
        nombre_archivo_csv = f"{nombre_base_csv}{contador_filas_total}.csv"
        df.to_csv(nombre_archivo_csv, index=False)
        print(f"Se ha guardado el DataFrame en '{nombre_archivo_csv}'")

# Al finalizar, mostrar un mensaje indicando que el proceso ha sido completado
print("Proceso completado.")
# Out:
# Cargando el último archivo CSV guardado: data2_25000.csv. Continuando desde la fila 50021.
# Proceso completado.

# %%
import pandas as pd
import requests
import os

def get_movie_budget(movie_id):
    url = f"https://api.themoviedb.org/3/movie/{movie_id}?language=en-US"
    headers = {
        "accept": "application/json",
        "Authorization": "Bearer ey7Xbvc6Hc"
    }
    response = requests.get(url, headers=headers)
    if response.status_code == 200:
        movie_data = response.json()
        budget = movie_data['budget']
        return budget
    else:
        print(f"Error al obtener los datos para la película con ID {movie_id}. Código de estado:", response.status_code)
        return None

nombre_base_csv = 'data6_'

contador_filas_total = 49500  # Comenzar desde la fila 25000

archivos_csv_guardados = [archivo for archivo in os.listdir() if archivo.startswith(nombre_base_csv)]

if archivos_csv_guardados:
    archivo_csv_ultimo = max(archivos_csv_guardados)
    df_anterior = pd.read_csv(archivo_csv_ultimo)
    contador_filas_total = len(df_anterior)
    print(f"Cargando el último archivo CSV guardado: {archivo_csv_ultimo}. Continuando desde la fila {contador_filas_total + 1}.")

# Iterar sobre las filas restantes del DataFrame original para obtener y actualizar el budget de cada película
for index, row in df.iloc[contador_filas_total:].iterrows():
    movie_id = row['id']
    print(f"Obteniendo información para la película con ID {movie_id}...")

    # Obtener el budget de la película
    budget = get_movie_budget(movie_id)

    if budget is not None and budget != 0:
        # Actualizar el DataFrame con el valor del budget correspondiente al ID de la película
        df.at[index, 'budget'] = budget
        print(f"Budget actualizado para la película con ID {movie_id}: {budget}")
    else:
        print(f"No se pudo obtener el budget o el budget es 0 para la película con ID {movie_id}")
        # Añadir la columna 'budget' con valor 0 al DataFrame en caso de que no se pueda obtener el budget o sea 0
        df.at[index, 'budget'] = 0

    # Incrementar el contador de filas total
    contador_filas_total += 1

    # Verificar si el contador de filas total es divisible por 5000 para guardar en un archivo CSV
    if contador_filas_total % 500 == 0:
        # Guardar el DataFrame en un nuevo archivo CSV
        nombre_archivo_csv = f"{nombre_base_csv}{contador_filas_total}.csv"
        df.to_csv(nombre_archivo_csv, index=False)
        print(f"Se ha guardado el DataFrame en '{nombre_archivo_csv}'")

# Al finalizar, mostrar un mensaje indicando que el proceso ha sido completado
print("Proceso completado.")
# Out:
# Obteniendo información para la película con ID 966861...
# No se pudo obtener el budget o el budget es 0 para la película con ID 966861
# Obteniendo información para la película con ID 952733...
# No se pudo obtener el budget o el budget es 0 para la película con ID 952733
# Obteniendo información para la película con ID 914783...
# No se pudo obtener el budget o el budget es 0 para la película con ID 914783
# Obteniendo información para la película con ID 911436...
# No se pudo obtener el budget o el budget es 0 para la película con ID 911436
# Obteniendo información para la película con ID 905075...
# No se pudo obtener el budget o el budget es 0 para la película con ID 905075
# Obteniendo información para la película con ID 903318...
# No se pudo obtener el budget o el budget es 0 para la película con ID 903318
# Obteniendo información para la película con ID 901193...
# No se pudo obtener el budget o el budget es 0 para la película con ID 901193
# ...
